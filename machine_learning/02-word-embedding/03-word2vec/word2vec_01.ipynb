# %% [markdown]
# # What is Word2Vec?
#
# **Word2Vec** is a technique that turns words into vectors (numbers) so that:
#
# * **Similar words** -> similar vectors
# * **Relationships are preserved** * *Example:* `king - man + woman ≈ queen`
#
# This overall concept is known as **word embeddings**.

# %% [markdown]
# ## Two Architectures (core idea)

# %% [markdown]
# 1. CBOW (Continuous Bag of Words)
# 2. Skip-gram (more powerful)

# %% [markdown]
# ### Example: CBOW (Continuous Bag of Words)
# Predict target word from context
#
# ```text
# "The cat sits on the mat"
# Context: ["The", "cat", "on", "the"]
# Target: "sits"
# ```

# %% [markdown]
# #### Example: Skip-gram (more powerful)
#
# Target: "sits"
# Predict: ["The", "cat", "on", "the"]

# %%
print("hello")
# Out:
# hello

# %%
from gensim.models import Word2Vec
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

sentences = [
    ["king", "is", "a", "strong", "man"],
    ["queen", "is", "a", "wise", "woman"],
    ["boy", "is", "a", "young", "man"],
    ["girl", "is", "a", "young", "woman"],
    ["prince", "is", "a", "young", "king"],
    ["princess", "is", "a", "young", "queen"]
]

sentences = [
    [word for word in sentence if word not in stop_words] 
    for sentence in sentences
]

model = Word2Vec(sentences, vector_size=50, window=2, min_count=1, sg=1, epochs=500)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/ankitsingh/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
print(model.wv["king"])
# Out:
# [-0.00018644  0.00625307 -0.01384475 -0.00254304  0.01515792  0.01455585
#  -0.00660885  0.00616761 -0.01747574  0.0126072  -0.00945429 -0.00649564
#   0.01824914  0.00166007  0.01500916 -0.01230943  0.01100858  0.02044254
#  -0.0176245  -0.01072548 -0.01401527 -0.0099135  -0.00667688 -0.01697023
#   0.01641329 -0.01017385  0.01703977  0.01105522 -0.01375431  0.00771436
#   0.01068114 -0.01522696 -0.01437253 -0.00586219 -0.01758277 -0.00327195
#   0.00015119  0.00618162  0.00312683 -0.00198747 -0.01150128  0.00337505
#  -0.00243267  0.01328456  0.00850883  0.00938539  0.0028039  -0.00520087
#  -0.00881382 -0.00153335]

# %%
# model.wv.most_similar("king")
# Out:
# [('queen', 0.18086792528629303),
#  ('girl', 0.1508084088563919),
#  ('woman', 0.1421230286359787),
#  ('boy', 0.11921563744544983),
#  ('princess', 0.10851433128118515),
#  ('prince', -0.05014173313975334),
#  ('wise', -0.06078771501779556),
#  ('young', -0.06988439708948135),
#  ('strong', -0.08063308149576187),
#  ('man', -0.18622300028800964)]
